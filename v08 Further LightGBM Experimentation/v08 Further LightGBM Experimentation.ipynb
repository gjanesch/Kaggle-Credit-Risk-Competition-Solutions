# %%
# Solution attempt 8: further lightgbm
# Final submission: 2018-07-08 
# Submission score: 0.788

# Further work with lightgbm, mostly feature engineering.
# Started this partially to snapshot the previous solution.

# %%
import numpy as np
import pandas as pd
import feather
import re
from lightgbm import LGBMClassifier

# %%
def has_NAs(pd_series):
    return pd_series.isnull().values.any()

# This is deleting stuff that it shouldn't
def string_col_to_onehot(df, col_name):
    dummy_cols = pd.get_dummies(df[col_name], drop_first = True, prefix = col_name)
    df.drop(columns = [col_name], inplace = True)
    return(pd.concat([df, dummy_cols], axis = 1))

# %%
# Load the main data files; don't load anything else yet, 'cause there's a lot
train = pd.read_feather("./../Data Files/application_train.feather")
test = pd.read_feather("./../Data Files/application_test.feather")

# Split off TARGET and establish a couple variables we'll need later
target = train["TARGET"]
train_IDs = train["SK_ID_CURR"]
train.drop("TARGET", inplace = True, axis = 1)
train_rows = len(train)
test_IDs = test["SK_ID_CURR"]

# %%
# Merge everything into a single dataset; this'll make processing easier.
all_data = pd.concat([train,test], ignore_index = True)

# These operations are a bit more consistent if they're done on the training & test sets together
building_info_columns = [c for c in train.columns.tolist() if re.search("_AVG$|_MODE$", c)]#("_AVG$|_MODE$|_MEDI$", c)]

# Columns removed due to low importance in lightgbm model
other_columns_to_remove = ["FLAG_MOBIL","FLAG_DOCUMENT_2","FLAG_DOCUMENT_4","FLAG_DOCUMENT_7","FLAG_DOCUMENT_9",
                           "FLAG_DOCUMENT_10","FLAG_DOCUMENT_12","FLAG_DOCUMENT_17","FLAG_DOCUMENT_19","FLAG_DOCUMENT_20",
                           "FLAG_CONT_MOBILE", "FLAG_EMP_PHONE"]

all_data.drop(building_info_columns + other_columns_to_remove, inplace = True, axis = 1)

# NEW STUFF
all_data["CREDIT_INCOME_RATIO"] = all_data["AMT_CREDIT"] / all_data["AMT_INCOME_TOTAL"]
all_data["INCOME_PER_HEAD"] = all_data["AMT_INCOME_TOTAL"] / all_data["CNT_FAM_MEMBERS"]
all_data["ANNUITY_INCOME_RATIO"] = all_data["AMT_ANNUITY"] / all_data["AMT_INCOME_TOTAL"]
all_data["ANNUITY_CREDIT_RATIO"] = all_data["AMT_ANNUITY"] / all_data["AMT_CREDIT"]

all_data["AMT_INCOME_TOTAL"] = np.log10(all_data["AMT_INCOME_TOTAL"])
all_data.loc[all_data["CODE_GENDER"] == "XNA", "CODE_GENDER"] = "F"
all_data.loc[all_data["DAYS_EMPLOYED"] == 365243, "DAYS_EMPLOYED"] = np.NaN

conditions = [all_data["CNT_CHILDREN"] == 0, all_data["CNT_CHILDREN"] == 1, all_data["CNT_CHILDREN"] >= 2]
choices = ["0","1","2+"]
all_data["CNT_CHILDREN"] = np.select(conditions, choices)

name_type_suite = all_data["NAME_TYPE_SUITE"]
all_data.loc[(name_type_suite != "Unaccompanied") & (~name_type_suite.isnull()), "NAME_TYPE_SUITE"] = "Accompanied"

object_cols = [col for col in all_data.columns if all_data[col].dtype == "O"]
for oc in object_cols:
    all_data = string_col_to_onehot(all_data, oc)

del name_type_suite

# %%
# Add data from bureau file
bureau = pd.read_feather("./../Data Files/bureau.feather")
bureau_balance = pd.read_feather("./../Data Files/bureau_balance.feather")
bureau = bureau.join(bureau_balance, on = "SK_ID_BUREAU", rsuffix = "bb")

bureau_grouped = bureau.groupby("SK_ID_CURR")
bureau_sub = bureau_grouped.agg({"CREDIT_DAY_OVERDUE":[lambda x: 1*any(x > 0),max],
                                 "AMT_CREDIT_SUM_OVERDUE":[max,sum],
                                 "CNT_CREDIT_PROLONG":sum,
                                 "AMT_CREDIT_SUM":sum,
                                 "AMT_CREDIT_SUM_DEBT":sum})
bureau_sub.columns = ["ANY_OVERDUE", "MAX_DAYS_OVERDUE", "MAX_CREDIT_OVERDUE", "NUM_TIMES_OVERDUE", "NUM_TIMES_PROLONGED",
                      "TOTAL_CURRENT_CREDIT_AMT", "TOTAL_CURRENT_CREDIT_DEBT"]
bureau_sub["CREDIT_COUNT"] = bureau_grouped.size()


all_data = all_data.join(bureau_sub, on = "SK_ID_CURR")#.fillna(0)
del bureau, bureau_sub, bureau_grouped, bureau_balance

# %%
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
# 3                   0                  NaN                NaN
# 4                   0               1197.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# 1                     NaN                   0        225000.0
# 2                     NaN                   0        464323.5
# 3                     NaN                   0         90000.0
# 4                 77674.5                   0       2700000.0
#
#    AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                  0.0                   NaN                     0.0
# 1             171342.0                   NaN                     0.0
# 2                  NaN                   NaN                     0.0
# 3                  NaN                   NaN                     0.0
# 4                  NaN                   NaN                     0.0
#
#        CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY  SK_ID_BUREAUbb  \
# 0  Consumer credit                -131          NaN         6066882
# 1      Credit card                 -20          NaN         6066882
# 2  Consumer credit                 -16          NaN         6066882
# 3      Credit card                 -16          NaN         6066884
# 4  Consumer credit                 -21          NaN         6066884
#
#    MONTHS_BALANCE STATUS
# 0             -24      0
# 1             -25      0
# 2             -26      0
# 3               0      C
# 4              -1      C

# %%
# Add data from previous_application
prev_application = pd.read_feather("./../Data Files/previous_application.feather")

app_credit_ratio = prev_application["AMT_APPLICATION"] - prev_application["AMT_CREDIT"]
prev_application["APP_CREDIT_RATIO"] = app_credit_ratio
conditions = [app_credit_ratio < 0, app_credit_ratio == 0, app_credit_ratio > 0]
choices = ["MORE_CREDIT_THAN_ASKED","EQUAL_TO_CREDIT_ASKED","LESS_CREDIT_THAN_ASKED"]
prev_application["RECEIVED_VS_APPLIED_CREDIT"] = np.select(conditions, choices)
del app_credit_ratio

prev_app_grouped = prev_application.groupby("SK_ID_CURR")
prev_app_sub = prev_app_grouped["NAME_CONTRACT_STATUS"].value_counts().unstack("NAME_CONTRACT_STATUS")

prev_app_sub.rename(columns = {"Approved":"NUMBER_APPROVED", "Canceled":"NUMBER_CANCELED",
                               "Refused":"NUMBER_REFUSED", "Unused offer":"NUMBER_UNUSED"},
                    inplace = True)
prev_app_sub["NUMBER_APPLICATIONS"] = prev_app_grouped.size()
prev_app_sub["LAST_DECISION_DATE"] = prev_app_grouped.agg({"DAYS_DECISION":min})["DAYS_DECISION"]

prev_app_sub2 = prev_app_grouped.agg({"AMT_CREDIT":[max,min,np.mean], "APP_CREDIT_RATIO":[max,min]})
prev_app_sub2.columns = ["MAX_CREDIT_REQUESTED","MIN_CREDIT_REQUESTED","AVG_CREDIT_REQUESTED","MAX_APP_CREDIT_RATIO",
                         "MIN_APP_CREDIT_RATIO"]

prev_app_sub3 = prev_app_grouped["RECEIVED_VS_APPLIED_CREDIT"].value_counts().unstack("RECEIVED_VS_APPLIED_CREDIT")
prev_app_sub3 = prev_app_sub3.iloc[:,1:]

prev_app_data = pd.concat([prev_app_sub, prev_app_sub2, prev_app_sub3], axis = 1).fillna(value = 0)

all_data = all_data.join(prev_app_data, on = "SK_ID_CURR")#.fillna(0)
del prev_application, prev_app_sub, prev_app_sub2, prev_app_sub3, prev_app_data

# %%
# Add credit card balance data
cc_balance = pd.read_feather("./../Data Files/credit_card_balance.feather")
cc_balance_grouped = cc_balance.groupby("SK_ID_CURR")
cc_balance_sub = cc_balance_grouped.agg({"SK_DPD_DEF":lambda x: sum(x != 0), "AMT_CREDIT_LIMIT_ACTUAL":max,
                                         "SK_ID_PREV":lambda x: len(x.unique()), "AMT_BALANCE":max,
                                         "AMT_PAYMENT_TOTAL_CURRENT":max, "CNT_DRAWINGS_CURRENT":max})
cc_balance_sub.rename(columns = {"SK_DPD_DEF":"NUM_LATE_CC_PAYMENTS",
                                 "AMT_CREDIT_LIMIT_ACTUAL":"MAX_CREDIT_LIMIT",
                                 "SK_ID_PREV":"NUM_PREV_CC_LOANS",
                                 "AMT_BALANCE":"MAX_BALANCE",
                                 "AMT_PAYMENT_TOTAL_CURRENT":"MAX_PAID_ON_CREDIT",
                                 "CNT_DRAWINGS_CURRENT":"MAX_DRAWINGS_IN_MONTH", }, inplace = True)
cc_balance_sub["AVG_CC_BALANCE"] = cc_balance_grouped["AMT_BALANCE"].mean()
cc_balance_sub["AVG_DRAWINGS_PER_MONTH"] = cc_balance_grouped["CNT_DRAWINGS_CURRENT"].mean()


all_data = all_data.join(cc_balance_sub, on = "SK_ID_CURR")#.fillna(0)
del cc_balance, cc_balance_grouped, cc_balance_sub

# %%
# Add installments_payments.csv data
install_paym = pd.read_feather("./../Data Files/installments_payments.feather")
install_paym["AMT_PAYMENT"].fillna(value = install_paym["AMT_INSTALMENT"], inplace = True)
install_paym["DAYS_ENTRY_PAYMENT"].fillna(value = install_paym["DAYS_INSTALMENT"], inplace = True)

install_paym["FRACTION_INSTALLMENT_PAID"] = install_paym["AMT_PAYMENT"] / install_paym["AMT_INSTALMENT"]
install_paym["PAYMENT_UNDER"] = install_paym["FRACTION_INSTALLMENT_PAID"] < 1
install_paym["DAYS_OFF_PAYMENT"] = install_paym["DAYS_INSTALMENT"] - install_paym["DAYS_ENTRY_PAYMENT"]
install_paym["PAYMENT_LATE"] = install_paym["DAYS_ENTRY_PAYMENT"] > install_paym["DAYS_INSTALMENT"]

install_paym_sub = install_paym.groupby("SK_ID_CURR").agg({"PAYMENT_UNDER":sum, "PAYMENT_LATE":sum,
                                                           "AMT_PAYMENT":[min,max],"DAYS_OFF_PAYMENT":[min,max],
                                                           "FRACTION_INSTALLMENT_PAID":[min,np.mean,max]})
install_paym_sub.columns = ["NUM_PAYMENTS_UNDER","NUM_PAYMENTS_LATE","MIN_PAYMENT","MAX_PAYMENT","BEST_PAYMENT_DATE",
                            "WORST_PAYMENT_DATE","MIN_INSTALL_FRAC_PAID","AVG_INSTALL_FRAC_PAID","MAX_INSTALL_FRAC_PAID"]

all_data = all_data.join(install_paym_sub, on = "SK_ID_CURR")#.fillna(0)

del install_paym, install_paym_sub

# %%
# Add POS_CASH_balance.csv data
POS_cash = pd.read_feather("./../Data Files/POS_CASH_balance.feather")
POS_cash_sub = POS_cash.groupby("SK_ID_CURR").agg({"SK_DPD_DEF":[lambda x: sum(x == 1),max,np.mean]})
POS_cash_sub.columns = ["NUM_LATE_POS_PAYMENTS", "MAX_DPD", "AVG_DPD"]
POS_cash_sub.head()

all_data = all_data.join(POS_cash_sub, on = "SK_ID_CURR")#.fillna(0)

del POS_cash, POS_cash_sub

# %%
all_data.drop(["SK_ID_CURR"], axis = 1, inplace = True)

# %%
train = all_data.iloc[:train_rows,:].copy()
test = all_data.iloc[train_rows:,:].copy()
train.reset_index(drop = True).to_feather("./../Solution attempts/v08 train data.feather")
test.reset_index(drop = True).to_feather("./../Solution attempts/v08 test data.feather")

# %%
pd.DataFrame({"SK_ID_CURR":train_IDs, "TARGET":target}).to_feather("./../Solution attempts/v07 target.feather")

# %%
# Train it up!
# 2018-07-08: Added "ANNUITY_CREDIT_RATIO", "MAX_DAYS_OVERDUE", "TOTAL_CURRENT_CREDIT", "TOTAL_CURRENT_CREDIT_DEBT", "AVG_CREDIT_REQUESTED","MAX_APP_CREDIT_RATIO",
# "MIN_APP_CREDIT_RATIO", "MAX_DPD", "AVG_DPD", "MIN_INSTALL_FRAC_PAID","AVG_INSTALL_FRAC_PAID","MAX_INSTALL_FRAC_PAID"; increased num_leaves parameter from 25 back to 30
# Previous val AUC: 0.783344

from sklearn.model_selection import KFold

folds = KFold(n_splits = 8, shuffle = True)
auc_scores = []

feature_importance_df = pd.DataFrame({"Features":train.columns})

lgbm_parameters = {"n_estimators":5000,
                   "learning_rate":0.01,     #previous: 0.03
                   "num_leaves":30,          #previous: 30
                   "colsample_by_tree":0.8,  #previous: 0.8
                   "subsample":0.9,          #previous: 0.9
                   "max_depth":7,            #previous: 7
                   "reg_alpha":0.15,         #previous: 0.1
                   "reg_lambda":0.01,        #previous: 0.1
                   "min_split_gain":0.1,     #previous: 0.1
                   "min_child_weight":2}     #previous: 0.1

for n_fold, (train_ids, val_ids) in enumerate(folds.split(train)):
    print("#### FOLD NUMBER " + str(n_fold + 1) + " ####")
    train_train = train.iloc[train_ids]
    train_test = train.iloc[val_ids]
    target_train = target[train_ids]
    target_test = target[val_ids]
    
    clf = LGBMClassifier(**lgbm_parameters)
    #clf = LGBMClassifier(n_estimators = 4000, learning_rate = 0.03, num_leaves = 30, colsample_by_tree = 0.75, subsample = 0.8, max_depth = 7, reg_alpha = 0.1, reg_lambda = 0.1, min_split_gain = 0.1, min_child_weight = 2)
    clf.fit(train_train, target_train, eval_set = [(train_train, target_train), (train_test, target_test)], eval_metric = "auc", early_stopping_rounds = 50, verbose = 100)
    auc_scores.append(clf._best_score["valid_1"]["auc"])
    feature_importance_df["Importance Fold " + str(n_fold + 1)] = pd.Series(clf.feature_importances_)
# Out:
# #### FOLD NUMBER 1 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.737406	valid_1's auc: 0.721216
# [200]	training's auc: 0.747471	valid_1's auc: 0.729946
# [300]	training's auc: 0.759985	valid_1's auc: 0.740533
# [400]	training's auc: 0.772941	valid_1's auc: 0.752656
# [500]	training's auc: 0.782117	valid_1's auc: 0.759772
# [600]	training's auc: 0.789116	valid_1's auc: 0.764436
# [700]	training's auc: 0.794952	valid_1's auc: 0.767841
# [800]	training's auc: 0.800054	valid_1's auc: 0.770095
# [900]	training's auc: 0.804567	valid_1's auc: 0.771888
# [1000]	training's auc: 0.808742	valid_1's auc: 0.773171
# [1100]	training's auc: 0.812824	valid_1's auc: 0.774321
# [1200]	training's auc: 0.816715	valid_1's auc: 0.775279
# [1300]	training's auc: 0.820366	valid_1's auc: 0.77591
# [1400]	training's auc: 0.823767	valid_1's auc: 0.776447
# [1500]	training's auc: 0.827174	valid_1's auc: 0.776898
# [1600]	training's auc: 0.830373	valid_1's auc: 0.777245
# [1700]	training's auc: 0.83343	valid_1's auc: 0.777509
# [1800]	training's auc: 0.836451	valid_1's auc: 0.77778
# [1900]	training's auc: 0.839506	valid_1's auc: 0.778038
# [2000]	training's auc: 0.84248	valid_1's auc: 0.77826
# [2100]	training's auc: 0.845242	valid_1's auc: 0.778424
# [2200]	training's auc: 0.847978	valid_1's auc: 0.778737
# [2300]	training's auc: 0.850612	valid_1's auc: 0.77884
# [2400]	training's auc: 0.853286	valid_1's auc: 0.778984
# [2500]	training's auc: 0.855864	valid_1's auc: 0.779162
# [2600]	training's auc: 0.858291	valid_1's auc: 0.779315
# [2700]	training's auc: 0.860687	valid_1's auc: 0.779382
# Early stopping, best iteration is:
# [2663]	training's auc: 0.859771	valid_1's auc: 0.779415
# #### FOLD NUMBER 2 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.737549	valid_1's auc: 0.72417
# [200]	training's auc: 0.747034	valid_1's auc: 0.731345
# [300]	training's auc: 0.760574	valid_1's auc: 0.742639
# [400]	training's auc: 0.773102	valid_1's auc: 0.752772
# [500]	training's auc: 0.782481	valid_1's auc: 0.759993
# [600]	training's auc: 0.789516	valid_1's auc: 0.764559
# [700]	training's auc: 0.79533	valid_1's auc: 0.767663
# [800]	training's auc: 0.800314	valid_1's auc: 0.770093
# [900]	training's auc: 0.805013	valid_1's auc: 0.771945
# [1000]	training's auc: 0.809172	valid_1's auc: 0.773281
# [1100]	training's auc: 0.813125	valid_1's auc: 0.774369
# [1200]	training's auc: 0.816851	valid_1's auc: 0.775214
# [1300]	training's auc: 0.820547	valid_1's auc: 0.776106
# [1400]	training's auc: 0.823926	valid_1's auc: 0.776704
# [1500]	training's auc: 0.827182	valid_1's auc: 0.777181
# [1600]	training's auc: 0.830444	valid_1's auc: 0.777613
# [1700]	training's auc: 0.833724	valid_1's auc: 0.778145
# [1800]	training's auc: 0.83678	valid_1's auc: 0.778545
# [1900]	training's auc: 0.839714	valid_1's auc: 0.778845
# [2000]	training's auc: 0.84268	valid_1's auc: 0.779088
# [2100]	training's auc: 0.845547	valid_1's auc: 0.779302
# [2200]	training's auc: 0.848221	valid_1's auc: 0.779524
# [2300]	training's auc: 0.850786	valid_1's auc: 0.779756
# [2400]	training's auc: 0.853359	valid_1's auc: 0.779903
# [2500]	training's auc: 0.855857	valid_1's auc: 0.780171
# [2600]	training's auc: 0.858298	valid_1's auc: 0.780403
# [2700]	training's auc: 0.860728	valid_1's auc: 0.780542
# Early stopping, best iteration is:
# [2719]	training's auc: 0.861163	valid_1's auc: 0.780583
# #### FOLD NUMBER 3 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.736296	valid_1's auc: 0.730339
# [200]	training's auc: 0.746731	valid_1's auc: 0.738889
# [300]	training's auc: 0.759618	valid_1's auc: 0.750384
# [400]	training's auc: 0.772437	valid_1's auc: 0.761164
# [500]	training's auc: 0.781561	valid_1's auc: 0.76833
# [600]	training's auc: 0.788465	valid_1's auc: 0.772985
# [700]	training's auc: 0.794306	valid_1's auc: 0.776085
# [800]	training's auc: 0.7994	valid_1's auc: 0.778322
# [900]	training's auc: 0.803948	valid_1's auc: 0.779899
# [1000]	training's auc: 0.808206	valid_1's auc: 0.781198
# [1100]	training's auc: 0.812171	valid_1's auc: 0.782076
# [1200]	training's auc: 0.816007	valid_1's auc: 0.782814
# [1300]	training's auc: 0.819648	valid_1's auc: 0.783565
# [1400]	training's auc: 0.823148	valid_1's auc: 0.784119
# [1500]	training's auc: 0.826532	valid_1's auc: 0.784443
# [1600]	training's auc: 0.829768	valid_1's auc: 0.784747
# [1700]	training's auc: 0.832813	valid_1's auc: 0.785287
# [1800]	training's auc: 0.835892	valid_1's auc: 0.7856
# [1900]	training's auc: 0.838787	valid_1's auc: 0.785992
# [2000]	training's auc: 0.841765	valid_1's auc: 0.786219
# [2100]	training's auc: 0.844594	valid_1's auc: 0.786385
# Early stopping, best iteration is:
# [2095]	training's auc: 0.844448	valid_1's auc: 0.786401
# #### FOLD NUMBER 4 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.73764	valid_1's auc: 0.727807
# [200]	training's auc: 0.748021	valid_1's auc: 0.734938
# [300]	training's auc: 0.760646	valid_1's auc: 0.744433
# [400]	training's auc: 0.773558	valid_1's auc: 0.754423
# [500]	training's auc: 0.782811	valid_1's auc: 0.760848
# [600]	training's auc: 0.789862	valid_1's auc: 0.765021
# [700]	training's auc: 0.795739	valid_1's auc: 0.767962
# [800]	training's auc: 0.801035	valid_1's auc: 0.770202
# [900]	training's auc: 0.805633	valid_1's auc: 0.771902
# [1000]	training's auc: 0.810006	valid_1's auc: 0.773171
# [1100]	training's auc: 0.814013	valid_1's auc: 0.774016
# [1200]	training's auc: 0.817755	valid_1's auc: 0.774884
# [1300]	training's auc: 0.82143	valid_1's auc: 0.775445
# [1400]	training's auc: 0.824902	valid_1's auc: 0.775845
# [1500]	training's auc: 0.828192	valid_1's auc: 0.776144
# [1600]	training's auc: 0.831469	valid_1's auc: 0.776362
# [1700]	training's auc: 0.834579	valid_1's auc: 0.776668
# [1800]	training's auc: 0.837686	valid_1's auc: 0.776919
# [1900]	training's auc: 0.840652	valid_1's auc: 0.77708
# [2000]	training's auc: 0.843594	valid_1's auc: 0.777319
# [2100]	training's auc: 0.846307	valid_1's auc: 0.777369
# [2200]	training's auc: 0.849072	valid_1's auc: 0.777394
# Early stopping, best iteration is:
# [2157]	training's auc: 0.84794	valid_1's auc: 0.777449
# #### FOLD NUMBER 5 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.735978	valid_1's auc: 0.732001
# [200]	training's auc: 0.746248	valid_1's auc: 0.741292
# [300]	training's auc: 0.75948	valid_1's auc: 0.752059
# [400]	training's auc: 0.772363	valid_1's auc: 0.76178
# [500]	training's auc: 0.781715	valid_1's auc: 0.768005
# [600]	training's auc: 0.788875	valid_1's auc: 0.771915
# [700]	training's auc: 0.794762	valid_1's auc: 0.774571
# [800]	training's auc: 0.800158	valid_1's auc: 0.776638
# [900]	training's auc: 0.804847	valid_1's auc: 0.778201
# [1000]	training's auc: 0.809106	valid_1's auc: 0.779331
# [1100]	training's auc: 0.812998	valid_1's auc: 0.780108
# [1200]	training's auc: 0.816852	valid_1's auc: 0.78086
# [1300]	training's auc: 0.820537	valid_1's auc: 0.781467
# [1400]	training's auc: 0.823978	valid_1's auc: 0.781941
# [1500]	training's auc: 0.827326	valid_1's auc: 0.782407
# [1600]	training's auc: 0.830615	valid_1's auc: 0.782798
# [1700]	training's auc: 0.833674	valid_1's auc: 0.78302
# [1800]	training's auc: 0.836777	valid_1's auc: 0.783189
# [1900]	training's auc: 0.83977	valid_1's auc: 0.783351
# [2000]	training's auc: 0.842622	valid_1's auc: 0.783578
# [2100]	training's auc: 0.84543	valid_1's auc: 0.783735
# [2200]	training's auc: 0.848051	valid_1's auc: 0.783951
# [2300]	training's auc: 0.850609	valid_1's auc: 0.784132
# [2400]	training's auc: 0.853177	valid_1's auc: 0.784249
# [2500]	training's auc: 0.855686	valid_1's auc: 0.78437
# [2600]	training's auc: 0.858142	valid_1's auc: 0.784555
# [2700]	training's auc: 0.860511	valid_1's auc: 0.784637
# [2800]	training's auc: 0.862971	valid_1's auc: 0.784784
# Early stopping, best iteration is:
# [2824]	training's auc: 0.863537	valid_1's auc: 0.784824
# #### FOLD NUMBER 6 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.736943	valid_1's auc: 0.735765
# [200]	training's auc: 0.746247	valid_1's auc: 0.743248
# [300]	training's auc: 0.759332	valid_1's auc: 0.753732
# [400]	training's auc: 0.772248	valid_1's auc: 0.763696
# [500]	training's auc: 0.781616	valid_1's auc: 0.770057
# [600]	training's auc: 0.788594	valid_1's auc: 0.773895
# [700]	training's auc: 0.794353	valid_1's auc: 0.776645
# [800]	training's auc: 0.799756	valid_1's auc: 0.779198
# [900]	training's auc: 0.804484	valid_1's auc: 0.780888
# [1000]	training's auc: 0.808702	valid_1's auc: 0.782017
# [1100]	training's auc: 0.812751	valid_1's auc: 0.783214
# [1200]	training's auc: 0.816474	valid_1's auc: 0.783876
# [1300]	training's auc: 0.820154	valid_1's auc: 0.784559
# [1400]	training's auc: 0.823534	valid_1's auc: 0.784992
# [1500]	training's auc: 0.826916	valid_1's auc: 0.785373
# [1600]	training's auc: 0.83009	valid_1's auc: 0.785924
# [1700]	training's auc: 0.833157	valid_1's auc: 0.786317
# [1800]	training's auc: 0.836187	valid_1's auc: 0.78664
# [1900]	training's auc: 0.839083	valid_1's auc: 0.786938
# [2000]	training's auc: 0.841925	valid_1's auc: 0.787254
# [2100]	training's auc: 0.844743	valid_1's auc: 0.787475
# [2200]	training's auc: 0.847471	valid_1's auc: 0.787665
# [2300]	training's auc: 0.850115	valid_1's auc: 0.787756
# [2400]	training's auc: 0.852694	valid_1's auc: 0.787974
# [2500]	training's auc: 0.855194	valid_1's auc: 0.788214
# [2600]	training's auc: 0.857577	valid_1's auc: 0.788316
# [2700]	training's auc: 0.859978	valid_1's auc: 0.788486
# [2800]	training's auc: 0.862413	valid_1's auc: 0.788601
# [2900]	training's auc: 0.864725	valid_1's auc: 0.788688
# [3000]	training's auc: 0.866973	valid_1's auc: 0.788836
# Early stopping, best iteration is:
# [3011]	training's auc: 0.867223	valid_1's auc: 0.78886
# #### FOLD NUMBER 7 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.736652	valid_1's auc: 0.733463
# [200]	training's auc: 0.746577	valid_1's auc: 0.741647
# [300]	training's auc: 0.759376	valid_1's auc: 0.751467
# [400]	training's auc: 0.772567	valid_1's auc: 0.762078
# [500]	training's auc: 0.781772	valid_1's auc: 0.768552
# [600]	training's auc: 0.788745	valid_1's auc: 0.772834
# [700]	training's auc: 0.794667	valid_1's auc: 0.775845
# [800]	training's auc: 0.799907	valid_1's auc: 0.778287
# [900]	training's auc: 0.804504	valid_1's auc: 0.779946
# [1000]	training's auc: 0.808722	valid_1's auc: 0.781038
# [1100]	training's auc: 0.812668	valid_1's auc: 0.782073
# [1200]	training's auc: 0.816376	valid_1's auc: 0.782729
# [1300]	training's auc: 0.819855	valid_1's auc: 0.783412
# [1400]	training's auc: 0.823293	valid_1's auc: 0.783859
# [1500]	training's auc: 0.826721	valid_1's auc: 0.784364
# [1600]	training's auc: 0.82992	valid_1's auc: 0.784627
# [1700]	training's auc: 0.833023	valid_1's auc: 0.784843
# [1800]	training's auc: 0.836111	valid_1's auc: 0.785256
# [1900]	training's auc: 0.83913	valid_1's auc: 0.785518
# [2000]	training's auc: 0.842006	valid_1's auc: 0.785639
# [2100]	training's auc: 0.844838	valid_1's auc: 0.785912
# [2200]	training's auc: 0.847749	valid_1's auc: 0.78613
# [2300]	training's auc: 0.850485	valid_1's auc: 0.786355
# [2400]	training's auc: 0.853062	valid_1's auc: 0.786382
# Early stopping, best iteration is:
# [2370]	training's auc: 0.852275	valid_1's auc: 0.786411
# #### FOLD NUMBER 8 ####
# Training until validation scores don't improve for 50 rounds.
# [100]	training's auc: 0.736401	valid_1's auc: 0.732556
# [200]	training's auc: 0.746277	valid_1's auc: 0.740193
# [300]	training's auc: 0.759417	valid_1's auc: 0.750804
# [400]	training's auc: 0.77259	valid_1's auc: 0.760773
# [500]	training's auc: 0.782095	valid_1's auc: 0.766681
# [600]	training's auc: 0.789418	valid_1's auc: 0.770726
# [700]	training's auc: 0.795184	valid_1's auc: 0.773188
# [800]	training's auc: 0.800436	valid_1's auc: 0.774899
# [900]	training's auc: 0.805079	valid_1's auc: 0.776288
# [1000]	training's auc: 0.809304	valid_1's auc: 0.77739
# [1100]	training's auc: 0.813176	valid_1's auc: 0.778351
# [1200]	training's auc: 0.816943	valid_1's auc: 0.778863
# [1300]	training's auc: 0.820579	valid_1's auc: 0.779392
# [1400]	training's auc: 0.82397	valid_1's auc: 0.779762
# [1500]	training's auc: 0.827391	valid_1's auc: 0.780252
# [1600]	training's auc: 0.830661	valid_1's auc: 0.780628
# [1700]	training's auc: 0.833847	valid_1's auc: 0.780921
# [1800]	training's auc: 0.836913	valid_1's auc: 0.781096
# [1900]	training's auc: 0.839888	valid_1's auc: 0.7813
# [2000]	training's auc: 0.842805	valid_1's auc: 0.781473
# [2100]	training's auc: 0.845584	valid_1's auc: 0.781582
# [2200]	training's auc: 0.848296	valid_1's auc: 0.781808
# [2300]	training's auc: 0.85097	valid_1's auc: 0.782044
# [2400]	training's auc: 0.853546	valid_1's auc: 0.782203
# [2500]	training's auc: 0.856032	valid_1's auc: 0.782418
# [2600]	training's auc: 0.858581	valid_1's auc: 0.782575
# [2700]	training's auc: 0.861063	valid_1's auc: 0.782727
# [2800]	training's auc: 0.863496	valid_1's auc: 0.782782
# Early stopping, best iteration is:
# [2764]	training's auc: 0.862602	valid_1's auc: 0.782806

# %%
feature_importance_df["Average Importance"] = feature_importance_df.iloc[:,1:].mean(axis=1)
feature_importance_df.to_csv("v08 Feature Importance.csv", index = False)
feature_importance_df
# Out:
#                          Features  Importance Fold 1  Importance Fold 2  \
# 0                AMT_INCOME_TOTAL                717                703
# 1                      AMT_CREDIT               1137               1121
# 2                     AMT_ANNUITY               1608               1518
# 3                 AMT_GOODS_PRICE               1168               1311
# 4      REGION_POPULATION_RELATIVE               1008               1047
# 5                      DAYS_BIRTH               2145               2225
# 6                   DAYS_EMPLOYED               2590               2586
# 7               DAYS_REGISTRATION               1361               1506
# 8                 DAYS_ID_PUBLISH               1598               1616
# 9                     OWN_CAR_AGE               1060               1047
# 10                FLAG_WORK_PHONE                186                194
# 11                     FLAG_PHONE                 81                103
# 12                     FLAG_EMAIL                 42                 15
# 13                CNT_FAM_MEMBERS                133                138
# 14           REGION_RATING_CLIENT                 78                 61
# 15    REGION_RATING_CLIENT_W_CITY                218                270
# 16        HOUR_APPR_PROCESS_START                540                576
# 17     REG_REGION_NOT_LIVE_REGION                 14                 31
# 18     REG_REGION_NOT_WORK_REGION                 18                 35
# 19    LIVE_REGION_NOT_WORK_REGION                 26                 22
# 20         REG_CITY_NOT_LIVE_CITY                147                161
# 21         REG_CITY_NOT_WORK_CITY                 20                 30
# 22        LIVE_CITY_NOT_WORK_CITY                 24                 49
# 23                   EXT_SOURCE_1               3544               3695
# 24                   EXT_SOURCE_2               3358               3303
# 25                   EXT_SOURCE_3               3686               3619
# 26                APARTMENTS_MEDI                605                631
# 27              BASEMENTAREA_MEDI                578                644
# 28   YEARS_BEGINEXPLUATATION_MEDI                812                757
# 29               YEARS_BUILD_MEDI                464                450
# ..                            ...                ...                ...
# 186           NUMBER_APPLICATIONS                278                315
# 187            LAST_DECISION_DATE               2074               2226
# 188          MAX_CREDIT_REQUESTED               1263               1246
# 189          MIN_CREDIT_REQUESTED                610                595
# 190          AVG_CREDIT_REQUESTED               1044               1138
# 191          MAX_APP_CREDIT_RATIO               1558               1532
# 192          MIN_APP_CREDIT_RATIO               1369               1455
# 193         EQUAL_TO_CREDIT_ASKED                255                334
# 194        LESS_CREDIT_THAN_ASKED                153                184
# 195        MORE_CREDIT_THAN_ASKED                175                221
# 196          NUM_LATE_CC_PAYMENTS                121                108
# 197              MAX_CREDIT_LIMIT                482                493
# 198             NUM_PREV_CC_LOANS                 27                 67
# 199                   MAX_BALANCE                450                566
# 200            MAX_PAID_ON_CREDIT                641                647
# 201         MAX_DRAWINGS_IN_MONTH                423                420
# 202                AVG_CC_BALANCE                759                824
# 203        AVG_DRAWINGS_PER_MONTH               1119               1038
# 204            NUM_PAYMENTS_UNDER                255                245
# 205             NUM_PAYMENTS_LATE                490                588
# 206                   MIN_PAYMENT               1292               1253
# 207                   MAX_PAYMENT               2020               2106
# 208             BEST_PAYMENT_DATE               1174               1194
# 209            WORST_PAYMENT_DATE               1330               1448
# 210         MIN_INSTALL_FRAC_PAID                489                536
# 211         AVG_INSTALL_FRAC_PAID               1307               1337
# 212         MAX_INSTALL_FRAC_PAID                357                341
# 213         NUM_LATE_POS_PAYMENTS                 48                 56
# 214                       MAX_DPD                322                336
# 215                       AVG_DPD                784                811
#
#      Importance Fold 3  Importance Fold 4  Importance Fold 5  \
# 0                  466                429                698
# 1                  867                913               1169
# 2                 1199               1191               1625
# 3                  994                954               1258
# 4                  700                719               1082
# 5                 1828               1901               2291
# 6                 1990               2070               2730
# 7                 1075               1075               1509
# 8                 1128               1222               1686
# 9                  790                819               1089
# 10                 157                144                198
# 11                  71                 77                 74
# 12                  12                  6                 22
# 13                  78                108                164
# 14                  57                 48                 62
# 15                 205                222                285
# 16                 363                425                579
# 17                  10                  9                 17
# 18                  14                 27                 13
# 19                  14                 10                 41
# 20                 159                133                188
# 21                  17                 24                 22
# 22                  42                 33                 76
# 23                3180               3153               3611
# 24                2920               2861               3440
# 25                3124               3159               3861
# 26                 427                523                717
# 27                 435                472                718
# 28                 510                531                861
# 29                 319                337                500
# ..                 ...                ...                ...
# 186                205                232                364
# 187               1603               1691               2103
# 188                850                901               1320
# 189                441                480                647
# 190                666                791               1212
# 191               1203               1218               1648
# 192               1078               1124               1612
# 193                185                198                283
# 194                107                127                143
# 195                170                177                232
# 196                 76                 78                134
# 197                416                388                530
# 198                 31                 46                 51
# 199                453                387                503
# 200                464                496                648
# 201                338                307                453
# 202                624                743                835
# 203                967                936               1109
# 204                181                177                267
# 205                399                437                586
# 206                849                970               1294
# 207               1668               1692               2036
# 208                939                889               1172
# 209               1021               1097               1433
# 210                391                383                573
# 211               1173               1109               1381
# 212                225                336                296
# 213                 27                 38                 59
# 214                279                237                315
# 215                625                652                760
#
#      Importance Fold 6  Importance Fold 7  Importance Fold 8  \
# 0                  767                570                721
# 1                 1314                998               1149
# 2                 1669               1258               1438
# 3                 1317               1152               1218
# 4                 1251                852               1042
# 5                 2454               2031               2153
# 6                 2847               2156               2610
# 7                 1712               1175               1581
# 8                 1795               1479               1659
# 9                 1089                985               1084
# 10                 209                193                214
# 11                  93                 92                 99
# 12                  30                 10                 20
# 13                 206                159                163
# 14                  73                 52                 71
# 15                 302                275                293
# 16                 720                497                600
# 17                  30                 14                 27
# 18                  46                 20                 22
# 19                  26                 20                 45
# 20                 151                146                174
# 21                  29                 16                 21
# 22                  75                 39                 21
# 23                3802               3228               3571
# 24                3563               3125               3381
# 25                4064               3467               3794
# 26                 696                522                749
# 27                 697                493                698
# 28                 857                635                809
# 29                 531                392                492
# ..                 ...                ...                ...
# 186                300                246                314
# 187               2390               1842               2107
# 188               1282                996               1267
# 189                795                553                674
# 190               1234                909               1156
# 191               1889               1356               1498
# 192               1642               1264               1444
# 193                345                254                282
# 194                137                146                182
# 195                239                192                248
# 196                140                112                158
# 197                558                457                515
# 198                 32                 40                 42
# 199                569                509                495
# 200                730                571                613
# 201                445                345                411
# 202                870                769                829
# 203               1052                954               1166
# 204                298                217                326
# 205                635                471                538
# 206               1503               1012               1360
# 207               2235               1905               2065
# 208               1353               1104               1277
# 209               1566               1148               1352
# 210                653                410                502
# 211               1492               1172               1317
# 212                332                267                390
# 213                 87                 38                 93
# 214                350                296                317
# 215                785                747                716
#
#      Average Importance
# 0               633.875
# 1              1083.500
# 2              1438.250
# 3              1171.500
# 4               962.625
# 5              2128.500
# 6              2447.375
# 7              1374.250
# 8              1522.875
# 9               995.375
# 10              186.875
# 11               86.250
# 12               19.625
# 13              143.625
# 14               62.750
# 15              258.750
# 16              537.500
# 17               19.000
# 18               24.375
# 19               25.500
# 20              157.375
# 21               22.375
# 22               44.875
# 23             3473.000
# 24             3243.875
# 25             3596.750
# 26              608.750
# 27              591.875
# 28              721.500
# 29              435.625
# ..                  ...
# 186             281.750
# 187            2004.500
# 188            1140.625
# 189             599.375
# 190            1018.750
# 191            1487.750
# 192            1373.500
# 193             267.000
# 194             147.375
# 195             206.750
# 196             115.875
# 197             479.875
# 198              42.000
# 199             491.500
# 200             601.250
# 201             392.750
# 202             781.625
# 203            1042.625
# 204             245.750
# 205             518.000
# 206            1191.625
# 207            1965.875
# 208            1137.750
# 209            1299.375
# 210             492.125
# 211            1286.000
# 212             318.000
# 213              55.750
# 214             306.500
# 215             735.000
#
# [216 rows x 10 columns]

# %%
print(auc_scores)
print(np.mean(auc_scores))
# Out:
# [0.7794146060820832, 0.7805830642928375, 0.7864012967131647, 0.777448980383821, 0.7848239891889099, 0.7888603200335452, 0.786411450300381, 0.782805929329628]
# 0.7833437045405464

# %%
# Below code is for second training regimen, should it be useful.
avg_importance = feature_importance_df["Average Importance"].tolist()
important_columns = [col for col,imp in zip(train.columns,avg_importance) if imp > 20]
len(important_columns)
train2 = train[important_columns]

# %%
clf2 = LGBMClassifier(**lgbm_parameters)
clf2.fit(train2, target, eval_set = [(train2, target)], eval_metric = "auc", early_stopping_rounds = 150, verbose = 50)
# Out:
# Training until validation scores don't improve for 150 rounds.
# [50]	training's auc: 0.730812
# [100]	training's auc: 0.736344
# [150]	training's auc: 0.740771
# [200]	training's auc: 0.745989
# [250]	training's auc: 0.75184
# [300]	training's auc: 0.758559
# [350]	training's auc: 0.764983
# [400]	training's auc: 0.770935
# [450]	training's auc: 0.775912
# [500]	training's auc: 0.780049
# [550]	training's auc: 0.783606
# [600]	training's auc: 0.786798
# [650]	training's auc: 0.789738
# [700]	training's auc: 0.792464
# [750]	training's auc: 0.794995
# [800]	training's auc: 0.797378
# [850]	training's auc: 0.799476
# [900]	training's auc: 0.801581
# [950]	training's auc: 0.803597
# [1000]	training's auc: 0.805485
# [1050]	training's auc: 0.807299
# [1100]	training's auc: 0.809087
# [1150]	training's auc: 0.810789
# [1200]	training's auc: 0.812499
# [1250]	training's auc: 0.81417
# [1300]	training's auc: 0.815871
# [1350]	training's auc: 0.817425
# [1400]	training's auc: 0.818988
# [1450]	training's auc: 0.820586
# [1500]	training's auc: 0.822123
# [1550]	training's auc: 0.823654
# [1600]	training's auc: 0.825131
# [1650]	training's auc: 0.826622
# [1700]	training's auc: 0.827971
# [1750]	training's auc: 0.829434
# [1800]	training's auc: 0.83083
# [1850]	training's auc: 0.832186
# [1900]	training's auc: 0.833578
# [1950]	training's auc: 0.834896
# [2000]	training's auc: 0.836213
# [2050]	training's auc: 0.837513
# [2100]	training's auc: 0.838909
# [2150]	training's auc: 0.840217
# [2200]	training's auc: 0.841477
# [2250]	training's auc: 0.842666
# [2300]	training's auc: 0.84385
# [2350]	training's auc: 0.84503
# [2400]	training's auc: 0.84626
# [2450]	training's auc: 0.847486
# [2500]	training's auc: 0.848698
# [2550]	training's auc: 0.849859
# [2600]	training's auc: 0.851032
# [2650]	training's auc: 0.852143
# [2700]	training's auc: 0.853331
# [2750]	training's auc: 0.854459
# [2800]	training's auc: 0.855509
# [2850]	training's auc: 0.8566
# [2900]	training's auc: 0.857661
# [2950]	training's auc: 0.858723
# [3000]	training's auc: 0.859795
# [3050]	training's auc: 0.860867
# [3100]	training's auc: 0.861833
# [3150]	training's auc: 0.862841
# [3200]	training's auc: 0.863891
# [3250]	training's auc: 0.864898
# [3300]	training's auc: 0.865915
# [3350]	training's auc: 0.866874
# [3400]	training's auc: 0.867896
# [3450]	training's auc: 0.868843
# [3500]	training's auc: 0.869744
# [3550]	training's auc: 0.870682
# [3600]	training's auc: 0.871637
# [3650]	training's auc: 0.872505
# [3700]	training's auc: 0.873418
# [3750]	training's auc: 0.874252
# [3800]	training's auc: 0.875236
# [3850]	training's auc: 0.876097
# [3900]	training's auc: 0.877018
# [3950]	training's auc: 0.877889
# [4000]	training's auc: 0.878722
# [4050]	training's auc: 0.87954
# [4100]	training's auc: 0.880361
# [4150]	training's auc: 0.881176
# [4200]	training's auc: 0.882038
# [4250]	training's auc: 0.88293
# [4300]	training's auc: 0.883771
# [4350]	training's auc: 0.884659
# [4400]	training's auc: 0.885458
# [4450]	training's auc: 0.886257
# [4500]	training's auc: 0.887065
# [4550]	training's auc: 0.887828
# [4600]	training's auc: 0.888645
# [4650]	training's auc: 0.889402
# [4700]	training's auc: 0.890206
# [4750]	training's auc: 0.890973
# [4800]	training's auc: 0.891785
# [4850]	training's auc: 0.892572
# [4900]	training's auc: 0.893367
# [4950]	training's auc: 0.894129
# [5000]	training's auc: 0.894871
# Did not meet early stopping. Best iteration is:
# [5000]	training's auc: 0.894871
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_by_tree=0.8,
#         colsample_bytree=1.0, learning_rate=0.01, max_depth=7,
#         min_child_samples=20, min_child_weight=2, min_split_gain=0.1,
#         n_estimators=5000, n_jobs=-1, num_leaves=30, objective=None,
#         random_state=None, reg_alpha=0.15, reg_lambda=0.01, silent=True,
#         subsample=0.9, subsample_for_bin=200000, subsample_freq=1)

# %%
data_predictions = clf2.predict_proba(test[important_columns], num_iteration = clf2.best_iteration_)
submission = pd.DataFrame({"SK_ID_CURR":test_IDs, "TARGET":data_predictions[:,1]})
submission.to_csv("v08_predictions.csv", index = False)
